# %%
import matplotlib_inline
print("Backend found!")

# Force the inline display
# %matplotlib inline
import matplotlib.pyplot as plt

# Quick test plot
plt.plot([0, 1], [0, 1])
plt.show()
# Out:
# Backend found!

# %%
import sys
import os
print(sys.executable)
print(sys.path)
# Out:
# /home/sajjad/gravitational-waves-LIGO/.venv/bin/python
# ['/usr/lib/python312.zip', '/usr/lib/python3.12', '/usr/lib/python3.12/lib-dynload', '', '/home/sajjad/gravitational-waves-LIGO/.venv/lib/python3.12/site-packages']
