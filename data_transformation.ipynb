# %%
from gwpy.timeseries import TimeSeries

t_merger = 1126259462.4
window = 4

# %%
print("getting data ...")

h1Data = TimeSeries.fetch_open_data("H1", t_merger - window, t_merger + window)

print("data is received")

print(dir(h1Data))
# Out:
# getting data ...
# data is received
# ['DictClass', 'T', '__abs__', '__add__', '__and__', '__array__', '__array_finalize__', '__array_function__', '__array_interface__', '__array_namespace__', '__array_priority__', '__array_struct__', '__array_ufunc__', '__array_wrap__', '__bool__', '__buffer__', '__class__', '__class_getitem__', '__complex__', '__contains__', '__copy__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__divmod__', '__dlpack__', '__dlpack_device__', '__doc__', '__eq__', '__firstlineno__', '__float__', '__floordiv__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getslice__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__iand__', '__ifloordiv__', '__ilshift__', '__imatmul__', '__imod__', '__imul__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__ior__', '__ipow__', '__irshift__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__lshift__', '__lt__', '__matmul__', '__metadata_finalize__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__quantity_subclass__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmatmul__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__setitem__', '__setstate__', '__sizeof__', '__static_attributes__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__xor__', '_compare_index', '_compatibility_error', '_decompose', '_default_unit', '_default_xunit', '_dx', '_equivalencies', '_include_easy_conversion_members', '_index_span', '_is_compatible_gwpy', '_is_compatible_numpy', '_metadata_slots', '_name', '_ndim', '_new_view', '_not_implemented_or_raise', '_print_slots', '_recursively_apply', '_repr_helper', '_repr_latex_', '_result_as_quantity', '_set_index', '_set_unit', '_to_own_unit', '_to_value', '_unit', '_unitstr', '_update_index', '_wrap_function', '_x0', 'abs', 'all', 'any', 'append', 'argmax', 'argmin', 'argpartition', 'argsort', 'asd', 'astype', 'auto_coherence', 'average_fft', 'bandpass', 'base', 'byteswap', 'cgs', 'channel', 'choose', 'clip', 'coherence', 'coherence_spectrogram', 'compress', 'conj', 'conjugate', 'convolve', 'copy', 'correlate', 'crop', 'csd', 'csd_spectrogram', 'ctypes', 'cumprod', 'cumsum', 'data', 'decompose', 'demodulate', 'detrend', 'device', 'diagonal', 'diff', 'dot', 'dt', 'dtype', 'dump', 'dumps', 'duration', 'dx', 'ediff1d', 'epoch', 'equivalencies', 'fetch', 'fetch_open_data', 'fft', 'fftgram', 'fill', 'filter', 'find', 'find_gates', 'flags', 'flat', 'flatten', 'from_lal', 'from_nds2_buffer', 'from_pycbc', 'gate', 'get', 'getfield', 'heterodyne', 'highpass', 'imag', 'info', 'inject', 'insert', 'is_compatible', 'is_contiguous', 'isscalar', 'item', 'itemsize', 'lowpass', 'mT', 'mask', 'max', 'mean', 'median', 'min', 'name', 'nbytes', 'ndim', 'nonzero', 'notch', 'override_unit', 'pad', 'partition', 'plot', 'prepend', 'prod', 'psd', 'put', 'q_gram', 'q_transform', 'ravel', 'rayleigh_spectrogram', 'rayleigh_spectrum', 'read', 'real', 'repeat', 'resample', 'reshape', 'resize', 'rms', 'round', 'sample_rate', 'searchsorted', 'setfield', 'setflags', 'shape', 'shift', 'si', 'size', 'sort', 'span', 'spectral_variance', 'spectrogram', 'spectrogram2', 'squeeze', 'std', 'step', 'strides', 'sum', 'swapaxes', 't0', 'take', 'taper', 'times', 'to', 'to_device', 'to_lal', 'to_pycbc', 'to_string', 'to_value', 'tobytes', 'tofile', 'tolist', 'tostring', 'trace', 'transfer_function', 'transpose', 'unit', 'update', 'value', 'value_at', 'var', 'view', 'whiten', 'write', 'x0', 'xindex', 'xspan', 'xunit', 'zip', 'zpk']

# %%
from gwpy.plot import Plot

plotH1 = Plot(h1Data, ylabel="Strain")
plotH1.show()
# Out:
# <Plot size 1200x600 with 1 Axes>

# %%
fftH1 = h1Data.fft()
fftMagnitude = fftH1.abs()
plotFft = fftMagnitude.plot()
ax = plotFft.gca()
ax.set_title("fft transformation")
plotFft.show()
# Out:
# <Plot size 640x480 with 1 Axes>

# %%
psdH1 = h1Data.psd()
plotPsd = psdH1.plot()
ax = plotPsd.gca()
ax.set_title("psd transformation")
plotPsd.show()
# Out:
# <Plot size 640x480 with 1 Axes>

# %%
asdH1 = h1Data.asd(2,1)
plotAsd = asdH1.plot()
ax = plotAsd.gca()
ax.set_title("asd transformation")
plotAsd.show()
# Out:
# <Plot size 640x480 with 1 Axes>
